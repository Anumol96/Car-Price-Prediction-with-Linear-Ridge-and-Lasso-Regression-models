# %% [markdown]
# ### Modeling and Prediction
#
# Regression model is used to model and predict the car price

# %% [markdown]
# #### Linear Regression

# %%
# importing necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

# %%
car_data = pd.read_csv('CarPrice_Assignment.csv')

#Splitting company name from CarName column
CompanyName = car_data['CarName'].apply(lambda x : x.split(' ')[0])
car_data.insert(3,"CompanyName",CompanyName)


# Now we can remove the car name column
car_data.drop(['CarName'],axis=1,inplace=True)

# %%
X= car_data.drop(['price','CompanyName'], axis=1)
y= car_data['price']

X = pd.get_dummies(data=X, drop_first=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model1 = LinearRegression()


model1.fit(X_train, y_train)
y_pred = model1.predict(X_test)

print (f'model : {model1} \nrmse score is : {np.sqrt(mean_squared_error(y_test, y_pred))}\nr2 score is {r2_score(y_test, y_pred)}')
# Out:
# model : LinearRegression()
# rmse score is : 2544.3930290366015
# r2 score is 0.9065599487796187

# %%
from yellowbrick.regressor import PredictionError, ResidualsPlot
from sklearn.preprocessing import StandardScaler

visualizer = PredictionError(model1)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.poof()
# Out:
# C:\Users\Anumol\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
visualizer = ResidualsPlot(model1)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.poof()
# Out:
# C:\Users\Anumol\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# #### Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score

# %%
# define model
model2 = Ridge(alpha=1.0)
# fit model
model2.fit(X_train, y_train)
# Out:
# Ridge()

# %%
y_pred = model2.predict(X_test)

print (f'model : {model2} \nrmse score is : {np.sqrt(mean_squared_error(y_test, y_pred))}\nr2 score is {r2_score(y_test, y_pred)}')
# Out:
# model : Ridge()
# rmse score is : 3059.860577236198
# r2 score is 0.864864967546952

# %%
visualizer = PredictionError(model2)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.poof()
# Out:
# C:\Users\Anumol\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'Prediction Error for Ridge'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
visualizer = ResidualsPlot(model2)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.poof()
# Out:
# C:\Users\Anumol\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but Ridge was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'Residuals for Ridge Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# #### Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
# define model
model3 = Lasso(alpha=1.0)
# fit model
model3.fit(X_train, y_train)
# define new data
# Out:
# Lasso()

# %%
y_pred = model3.predict(X_test)

print (f'model : {model3} \nrmse score is : {np.sqrt(mean_squared_error(y_test, y_pred))}\nr2 score is {r2_score(y_test, y_pred)}')
# Out:
# model : Lasso()
# rmse score is : 2578.5936257542326
# r2 score is 0.9040311074436326

# %%
visualizer = PredictionError(model3)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.poof()
# Out:
# C:\Users\Anumol\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'Prediction Error for Lasso'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
visualizer = ResidualsPlot(model3)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.poof()
# Out:
# C:\Users\Anumol\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# <AxesSubplot:title={'center':'Residuals for Lasso Model'}, xlabel='Predicted Value', ylabel='Residuals'>
